# %%
from langgraph.graph import StateGraph, START, END
print("LangGraph installed successfully!")
# Out:
# LangGraph installed successfully!

# %%
# %pip install -U langchain-ollama
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-ollama) (1.6.1)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain-ollama)
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.11.2)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\owner\Anaconda3\envs\agent\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.7.0)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Installing collected packages: ollama, langchain-ollama
#
#    ---------------------------------------- 2/2 [langchain-ollama]
#
# Successfully installed langchain-ollama-1.1.0 ollama-0.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
import os
import langchain_ollama
from langchain_ollama import ChatOllama

# %%
llm1 = ChatOllama(
    model="llama3.2:3b",
    temperature=0
)

# %%
response1 = llm1.invoke("Explain LangGraph in one sentence.")
print(response1.content)
# Out:
# LangGraph is an open-source, Python-based framework for building and training neural networks, particularly designed for natural language processing (NLP) tasks, offering a simple and efficient way to create and deploy models.

# %%
## State 可以理解成：数据在整个工作流里传来传去的容器

class State(TypedDict):
    text: str
    result: str

# %%
def clean_text(state: State):
    text = state["text"].strip()
    return {"text": text}


def summarize(state: State):
    prompt = f"""
    Summarize the following text clearly and concisely.

    Text:
    {state["text"]}
    """

    response = llm1.invoke(prompt)

    return {"result": response.content}

# %%
## first langGraph workflow
builder = StateGraph(State)
builder.add_node("clean_text", clean_text)
builder.add_node("summarize", summarize)

## conecting nodes
builder.add_edge(START, "clean_text")  # from start to clean_text node
builder.add_edge("clean_text", "summarize")   # from clean_text to summarize node
builder.add_edge("summarize", END)

graph1 = builder.compile()

# %%
result1 = graph1.invoke({
    "text": """
LangGraph is an open-source orchestration framework 
created by LangChain designed specifically for building 
complex, stateful, multi-agent AI workflows. While standard 
LangChain is built for linear pipelines ("chains"), 
LangGraph models workflows as cyclic graphs, 
allowing AI agents to loop back, branch out, 
self-correct, and maintain a flexible control flow.
    """,
    "result": ""
})

print(result1['result'])
# Out:
# Here is a clear and concise summary of the text:
#
# LangGraph is an open-source framework that allows for building complex, stateful AI workflows with multi-agent capabilities. It differs from standard LangChain by modeling workflows as cyclic graphs, enabling agents to loop, branch, and self-correct.
