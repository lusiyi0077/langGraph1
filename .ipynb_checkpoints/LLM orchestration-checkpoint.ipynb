# %% [markdown]
# # orchestration example

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_ollama import ChatOllama

# %%
class State(TypedDict):
    text: str
    category: str
    draft: str
    final: str

# %%
llm = ChatOllama(
    model="llama3.2:3b",
    temperature=0
)

# %% [markdown]
# # node 1 : classify

# %%
def classify(state: State):
    prompt = f"""
    Classify the following text into exactly one category:

    news
    email
    other

    Return only the category name.

    Text:
    {state["text"]}
    """

    response = llm.invoke(prompt)

    category = response.content.strip().lower()

    return {"category": category}

# %% [markdown]
# # node 2 summarize news

# %%
def summarize_news(state: State):
    prompt = f"""
    Summarize this news article concisely.

    Focus on:
    - key event
    - important people or companies
    - business impact

    Text:
    {state["text"]}
    """

    response = llm.invoke(prompt)

    return {"draft": response.content}

# %% [markdown]
# # node 3 summarize emails

# %%
def summarize_email(state: State):
    prompt = f"""
    Summarize this email.

    Identify:
    - sender's main message
    - requested action
    - any deadline

    Text:
    {state["text"]}
    """

    response = llm.invoke(prompt)

    return {"draft": response.content}

# %% [markdown]
# # node 4 summarize other text

# %%
def summarize_general(state: State):
    prompt = f"""
    Summarize the following text clearly and concisely.

    Text:
    {state["text"]}
    """

    response = llm.invoke(prompt)

    return {"draft": response.content}

# %% [markdown]
# # routing

# %%
def routeing(state: State):
    category = state["category"]

    if "news" in category:
        return "news"

    elif "email" in category:
        return "email"

    else:
        return "other"
